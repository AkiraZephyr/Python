# %%
import cv2 
import matplotlib.pyplot as plt

# %%
img = cv2.imread("C:\\Academics\\Python\\Digital Image Processing\\download.jpeg", 0)

# %%
equalized_img = cv2.equalizeHist(img)

# %%
#Show Original vs Equalized 
plt.figure(figsize=(10,5))
# Original Image 
plt.subplot(1,2,1) 
plt.title("Original Image") 
plt.imshow(img, cmap='gray') 
plt.axis("off") 

# Equalized Image 
plt.subplot(1,2,2) 
plt.title("Equalized Image") 
plt.imshow(equalized_img, cmap='gray') 
plt.axis("off") 
plt.show()

# %%
#graph for pixel integrity for both images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("Original Image Histogram")
plt.hist(img.ravel(), 256, [0, 256])
plt.subplot(1,2,2)
plt.title("Equalized Image Histogram")
plt.hist(equalized_img.ravel(), 256, [0, 256])
plt.show()
# Out:
# C:\Users\Philip\AppData\Local\Temp\ipykernel_2176\1738072526.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])
# C:\Users\Philip\AppData\Local\Temp\ipykernel_2176\1738072526.py:8: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(equalized_img.ravel(), 256, [0, 256])
