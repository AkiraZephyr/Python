# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 
img = cv2.imread("C:\\Academics\\Python\\Digital Image Processing\\FullMoon.jpg", 0) 
dft = np.fft.fft2(img) 
dft_shift = np.fft.fftshift(dft) 
magnitude_spectrum = 20*np.log(np.abs(dft_shift))
plt.figure(figsize=(10,7))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title("Fourier Spectrum")
plt.show()

# %%
#output original and fourier in matplot
plt.figure(figsize=(10,7))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title("Fourier Spectrum")
plt.show()
